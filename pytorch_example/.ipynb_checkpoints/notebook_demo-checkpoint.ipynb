# %%
import numpy as np
import sh
import sys
import os
import csv
import glob

def main():
    # mp3_dir = "mp3"

    feature_dir = "feature"
    model_dir = "model"
    prediction_wav_dir = "prediction_wav"
    read_dir = "read"
    padding_dir = "padding"
    redimension_dir = "redimension"
    window_dir = "window"
    sample_csv_dir = "sample_csv"
    wav_dir = "wav"
    dir_name = feature_dir +" "+ model_dir +" "+ prediction_wav_dir +" "+ read_dir +" "+ padding_dir +" "+ redimension_dir +" "+ sample_csv_dir  +" "+ wav_dir+" "+ window_dir
    sh.run("mkdir -p "+ dir_name)
    #sh.run("rm -rf "+str_name)

    # mp3_to_wav.run(mp3_file, wav_dir)
    wav_train__dir = wav_dir + "/" + "train"
    wav_prediction_dir = wav_dir + "/" + "prediction"
    csv_train_dir = sample_csv_dir + "/" + "train"
    csv_prediction_dir = sample_csv_dir + "/" + "prediction"
    redim_train_dir = redimension_dir+ "/" + "train"
    redim_test_dir = redimension_dir+ "/" +"test"
    sub_dir = wav_train__dir +" "+ wav_prediction_dir +" "+ csv_train_dir +" "+ csv_prediction_dir +" "+redim_train_dir +" "+redim_test_dir
    sh.run("mkdir -p "+ sub_dir)

    labels = []
    for i, f in enumerate(glob.glob(sample_csv_dir + os.sep +'*')):
        # print f
        for j,f_sub in enumerate(glob.glob(f + os.sep +'*.csv')):
            # print f_sub
            sample_file = f_sub
            with open(sample_file, 'rb') as csvfile:

            	reader = csv.reader(csvfile, delimiter=',', quotechar='|')

                for k, row in enumerate(reader):
                    labels.append(row[2])


    print np.unique(labels)
    for l in np.unique(labels):
        print l
        sh.run("mkdir -p "+ read_dir +"/"+ l)
        sh.run("mkdir -p "+ padding_dir +"/"+ l)
        # sh.run("mkdir -p "+ redimension_dir +"/"+ l)
        sh.run("mkdir -p "+ redim_train_dir +"/"+ l)
        sh.run("mkdir -p "+ redim_test_dir +"/"+ l)
        sh.run("mkdir -p "+ prediction_wav_dir +"/"+ l)


if __name__ == '__main__':
	main()
# Out:
# mkdir -p feature model prediction_wav read padding redimension sample_csv wav window
# mkdir -p wav/train wav/prediction sample_csv/train sample_csv/prediction redimension/train redimension/test
# ['Ba' 'Bm' 'Eg']
# Ba
# mkdir -p read/Ba
# mkdir -p padding/Ba
# mkdir -p redimension/train/Ba
# mkdir -p redimension/test/Ba
# mkdir -p prediction_wav/Ba
# Bm
# mkdir -p read/Bm
# mkdir -p padding/Bm
# mkdir -p redimension/train/Bm
# mkdir -p redimension/test/Bm
# mkdir -p prediction_wav/Bm
# Eg
# mkdir -p read/Eg
# mkdir -p padding/Eg
# mkdir -p redimension/train/Eg
# mkdir -p redimension/test/Eg
# mkdir -p prediction_wav/Eg

# %%
from datetime import datetime, timedelta, tzinfo
import sys
import numpy as np
import os
import csv
import glob
import sh

class FixedOffset(tzinfo):
    """offset_str: Fixed offset in str: e.g. '-0400'"""
    def __init__(self, offset_str):
        sign, hours, minutes = offset_str[0], offset_str[1:3], offset_str[3:]
        offset = (int(hours) * 60 + int(minutes)) * (-1 if sign == "-" else 1)
        self.__offset = timedelta(minutes=offset)
        # NOTE: the last part is to remind about deprecated POSIX GMT+h timezones
        # that have the opposite sign in the name;
        # the corresponding numeric value is not used e.g., no minutes
        '<%+03d%02d>%+d' % (int(hours), int(minutes), int(hours)*-1)
    def utcoffset(self, dt=None):
        return self.__offset
    def tzname(self, dt=None):
        return self.__name
    def dst(self, dt=None):
        return timedelta(0)
    def __repr__(self):
        return 'FixedOffset(%d)' % (self.utcoffset().total_seconds() / 60)

def read(csv_train_dir):
    segProjet = []
    segSite = []
    segStart = []
    #segEnd = []
    segLabel = []
    duration = []
    segQuality = []
    for j,sample_file in enumerate(glob.glob(csv_train_dir + os.sep +'*.csv')):
#         print sample_file
        with open(sample_file, 'rb') as csvfile:
            reader = csv.reader(csvfile, delimiter=',', quotechar='|')
            for j, row in enumerate(reader):
                segProjet.append(row[0])
                segSite.append(row[1])
                date_with_tz = row[3]
                #print date_with_tz

                start = datetime.strptime(date_with_tz, "%Y-%m-%dT%H:%M:%S.%f")

                #start = datetime.datetime.strptime(row[3], "%Y-%m-%dT%H:%M:%S")
                segStart.append(start)
                #segEnd.append(row[4])
                end = datetime.strptime(row[4], "%Y-%m-%dT%H:%M:%S.%f")
                segLabel.append(row[2])
                dur = (end - start).total_seconds()
                duration.append(dur)

                segQuality.append(row[5])
                #print dur
        #print segProjet,segSite,segStart,duration,segLabel,segQuality

    return segProjet,segSite,segStart,duration,segLabel,segQuality

def date_type(wav_dir,segProjet,segSite,segStart,duration,segLabel,segQuality,read_dir):
    print max(duration)
    print min(duration)
    for i, f in enumerate(glob.glob(wav_dir + os.sep +'*.wav')):               # for each WAV file
        wavFile = f
#         print os.path.splitext(wavFile)[0]
        waveFile_name = (os.path.splitext(wavFile)[0]).split(os.sep)[2]
#         print waveFile_name
        date1 = waveFile_name.split("_")[3]
        date2 = (waveFile_name.split("_")[4]).split(".")[0]
        #print date1,date2
        temp1 = []
        temp2 = []
        for i in range(len(date1)):
            #print date1[i], '(%d)' %i
            temp1.append(date1[i])
        date1 = "20" + temp1[0] + temp1[1] +"-"+ temp1[2] + temp1[3] +"-"+ temp1[4]+temp1[5]
#         print ("date1 is ",date1)

        for j in range(len(date2)):
            #print date2[j], '(%d)' %j
            temp2.append(date2[j])
        date2 = temp2[0] + temp2[1] +":"+ temp2[2] + temp2[3] +":"+ temp2[4]+temp2[5]
        #print date2

        date_str = date1 +" "+ date2
        #print data_str

        start_date = datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S")

#         print ("start_date is ",start_date)
        
        cut(wavFile, segProjet,segSite,segStart,duration,segLabel,segQuality, read_dir,start_date)


        
def cut(wavFile,segProjet,segSite,segStart,duration,segLabel,segQuality, read_dir,start_date):
    # date2 = datetime.strptime(date2, "%H:%M:%S")
    #print("date2 is ",date2)
    cmd = """ffmpeg -i """ + wavFile + """ 2>&1 | grep "Duration"| cut -d ' ' -f 4 | sed s/,// | awk '{ split($1, A, ":"); print 3600*A[1] + 60*A[2] + A[3] }'"""
    rs = sh.run(cmd, True)

    duration_in_wavFile = rs.stdout()
#     print("the duration of wavfile is ", duration_in_wavFile)
    # print type(duration_in_wavFile)
    # print type(duration)

    w = os.path.splitext(wavFile)[0]
    projet_wav = w.split("_")[0]
    site_wav = w.split("_")[1]

    good_projet = []
    good_site = []
    good_species = []
    good_start = []
    good_cut_point = []
    good_duration = []
    good_quality = []
    for i in range(0, len(segStart)):
        if i < len(segStart) - 1:
            cut_point = (segStart[i] - start_date).total_seconds()
            #print cut_point
            #print type(cut_point)

            if cut_point >= 0 and float(cut_point) <= float(duration_in_wavFile):
                good_projet.append(segProjet[i])
                good_site.append(segSite[i])
                good_species.append(segLabel[i])

                temp_start = segStart[i].strftime("%Y-%m-%dT%H:%M:%S.%f")
                temp_start = temp_start[:-5]
                good_start.append(temp_start)

                good_cut_point.append(cut_point)
                good_duration.append(duration[i])
                good_quality.append(segQuality[i])
#     print good_cut_point,str(good_duration)
#     print good_start
    encode_good_speices = np.unique(good_species)
    for j in range(0,len(good_cut_point)):
        str_name = str(good_projet[j]) +"_"+ str(good_site[j]) +"_"+ str(good_start[j]) +"."+ str(good_species[j]) +"."+ str(good_quality[j])
        for s in encode_good_speices:
            if str(good_species[j]) == s and str(good_projet[j]==projet_wav) and str(good_site[j])==site_wav:
                cmd = "ffmpeg -ss " + str(good_cut_point[j]) + " -t " + str(good_duration[j])+ " -i " + wavFile + " " + read_dir + "/" + s + "/" + str_name + ".wav"
                sh.run(cmd)        
        
def clean(file_dir):
    for i, f in enumerate(glob.glob(file_dir + os.sep +'*')):
        # print f
        cmd = "rm -rf " + f  + "/*.wav"
        sh.run(cmd)

if __name__ == '__main__':

    csv_train_dir = "sample_csv/train"

    wav_dir = 'wav/train'
    read_dir = "read"
    clean(read_dir)
    segProjet,segSite,segStart,duration,segLabel,segQuality = read(csv_train_dir)
    date_type(wav_dir,segProjet,segSite,segStart,duration,segLabel,segQuality,read_dir)
# Out:
# rm -rf read/Bm/*.wav
# rm -rf read/Eg/*.wav
# rm -rf read/Ba/*.wav
# 43.1
# 1.0
# ffmpeg -i wav/train/WAT_HZ_01_160124_170000.df100.x.wav 2>&1 | grep "Duration"| cut -d ' ' -f 4 | sed s/,// | awk '{ split($1, A, ":"); print 3600*A[1] + 60*A[2] + A[3] }'
# ffmpeg -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav 2>&1 | grep "Duration"| cut -d ' ' -f 4 | sed s/,// | awk '{ split($1, A, ":"); print 3600*A[1] + 60*A[2] + A[3] }'
# ffmpeg -ss 139.1 -t 8.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:02:19.1.Bm.good.wav
# ffmpeg -ss 204.3 -t 6.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:03:24.3.Bm.good.wav
# ffmpeg -ss 273.6 -t 7.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:04:33.6.Bm.good.wav
# ffmpeg -ss 336.6 -t 5.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:05:36.6.Bm.good.wav
# ffmpeg -ss 397.9 -t 4.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:06:37.9.Bm.good.wav
# ffmpeg -ss 450.2 -t 2.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:07:30.2.Bm.good.wav
# ffmpeg -ss 521.6 -t 3.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:08:41.6.Bm.good.wav
# ffmpeg -ss 533.3 -t 1.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:08:53.3.Bm.good.wav
# ffmpeg -ss 677.9 -t 5.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:11:17.9.Bm.good.wav
# ffmpeg -ss 697.5 -t 9.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:11:37.5.Bm.good.wav
# ffmpeg -ss 760.4 -t 5.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:12:40.4.Bm.good.wav
# ffmpeg -ss 820.8 -t 4.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:13:40.8.Bm.good.wav
# ffmpeg -ss 879.5 -t 5.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:14:39.5.Bm.good.wav
# ffmpeg -ss 997.5 -t 6.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:16:37.5.Bm.good.wav
# ffmpeg -ss 1063.7 -t 3.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:17:43.7.Bm.good.wav
# ffmpeg -ss 1073.6 -t 6.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:17:53.6.Bm.good.wav
# ffmpeg -ss 1278.7 -t 4.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:21:18.7.Bm.good.wav
# ffmpeg -ss 1301.3 -t 2.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:21:41.3.Bm.poor.wav
# ffmpeg -ss 1349.9 -t 8.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:22:29.9.Bm.good.wav
# ffmpeg -ss 1360.5 -t 6.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:22:40.5.Bm.good.wav
# ffmpeg -ss 1428.5 -t 11.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:23:48.5.Bm.good.wav
# ffmpeg -ss 1510.9 -t 7.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:25:10.9.Bm.good.wav
# ffmpeg -ss 1921.8 -t 13.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:32:01.8.Bm.good.wav
# ffmpeg -ss 1990.0 -t 6.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:33:10.0.Bm.good.wav
# ffmpeg -ss 2001.1 -t 6.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:33:21.1.Bm.good.wav
# ffmpeg -ss 2224.4 -t 11.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:37:04.4.Bm.good.wav
# ffmpeg -ss 2291.9 -t 7.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:38:11.9.Bm.good.wav
# ffmpeg -ss 2402.9 -t 4.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:40:02.9.Bm.good.wav
# ffmpeg -ss 2427.6 -t 5.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:40:27.6.Bm.good.wav
# ffmpeg -ss 2484.8 -t 4.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:41:24.8.Bm.good.wav
# ffmpeg -ss 2494.6 -t 5.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:41:34.6.Bm.good.wav
# ffmpeg -ss 2553.2 -t 5.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:42:33.2.Bm.good.wav
# ffmpeg -ss 2634.6 -t 9.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:43:54.6.Bm.good.wav
# ffmpeg -ss 2760.6 -t 6.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:46:00.6.Bm.good.wav
# ffmpeg -ss 2827.5 -t 4.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:47:07.5.Bm.good.wav
# ffmpeg -ss 2881.2 -t 7.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:48:01.2.Bm.good.wav
# ffmpeg -ss 2942.9 -t 4.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:49:02.9.Bm.good.wav
# ffmpeg -ss 2994.1 -t 5.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:49:54.1.Bm.good.wav
# ffmpeg -ss 3050.9 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:50:50.9.Bm.good.wav
# ffmpeg -ss 3061.1 -t 5.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:51:01.1.Bm.good.wav
# ffmpeg -ss 3219.0 -t 4.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:53:39.0.Bm.poor.wav
# ffmpeg -ss 3279.9 -t 5.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:54:39.9.Bm.good.wav
# ffmpeg -ss 3336.1 -t 5.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:55:36.1.Bm.good.wav
# ffmpeg -ss 3379.5 -t 3.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:56:19.5.Bm.good.wav
# ffmpeg -ss 3400.3 -t 4.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:56:40.3.Bm.good.wav
# ffmpeg -ss 3461.3 -t 6.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:57:41.3.Bm.good.wav
# ffmpeg -ss 3586.6 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T00:59:46.6.Bm.good.wav
# ffmpeg -ss 3816.2 -t 4.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:03:36.2.Bm.good.wav
# ffmpeg -ss 3876.1 -t 9.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:04:36.1.Bm.good.wav
# ffmpeg -ss 3943.6 -t 5.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:05:43.6.Bm.good.wav
# ffmpeg -ss 3957.0 -t 3.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:05:57.0.Bm.good.wav
# ffmpeg -ss 3974.9 -t 4.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:06:14.9.Bm.good.wav
# ffmpeg -ss 4058.2 -t 3.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:07:38.2.Bm.good.wav
# ffmpeg -ss 4117.8 -t 6.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:08:37.8.Bm.good.wav
# ffmpeg -ss 4184.8 -t 3.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:09:44.8.Bm.good.wav
# ffmpeg -ss 4196.3 -t 3.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:09:56.3.Bm.good.wav
# ffmpeg -ss 4341.4 -t 8.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:12:21.4.Bm.good.wav
# ffmpeg -ss 4406.5 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:13:26.5.Bm.good.wav
# ffmpeg -ss 4458.4 -t 6.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:14:18.4.Bm.good.wav
# ffmpeg -ss 4500.0 -t 3.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:15:00.0.Bm.good.wav
# ffmpeg -ss 4525.0 -t 4.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:15:25.0.Bm.good.wav
# ffmpeg -ss 4583.1 -t 2.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:16:23.1.Bm.good.wav
# ffmpeg -ss 4591.4 -t 6.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:16:31.4.Bm.good.wav
# ffmpeg -ss 6134.9 -t 6.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:42:14.9.Bm.good.wav
# ffmpeg -ss 6151.6 -t 2.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:42:31.6.Bm.good.wav
# ffmpeg -ss 6198.7 -t 5.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:43:18.7.Bm.good.wav
# ffmpeg -ss 6208.5 -t 6.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:43:28.5.Bm.good.wav
# ffmpeg -ss 6233.6 -t 2.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:43:53.6.Bm.good.wav
# ffmpeg -ss 6444.7 -t 4.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:47:24.7.Bm.poor.wav
# ffmpeg -ss 6527.8 -t 5.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:48:47.8.Bm.good.wav
# ffmpeg -ss 6609.7 -t 5.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:50:09.7.Bm.good.wav
# ffmpeg -ss 6671.6 -t 3.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:51:11.6.Bm.good.wav
# ffmpeg -ss 6740.0 -t 3.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:52:20.0.Bm.poor.wav
# ffmpeg -ss 6802.2 -t 4.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:53:22.2.Bm.good.wav
# ffmpeg -ss 6811.8 -t 6.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:53:31.8.Bm.good.wav
# ffmpeg -ss 6876.5 -t 4.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:54:36.5.Bm.good.wav
# ffmpeg -ss 6941.5 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:55:41.5.Bm.good.wav
# ffmpeg -ss 7004.6 -t 4.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:56:44.6.Bm.good.wav
# ffmpeg -ss 7014.4 -t 7.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:56:54.4.Bm.good.wav
# ffmpeg -ss 7155.2 -t 11.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T01:59:15.2.Bm.good.wav
# ffmpeg -ss 7203.6 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:00:03.6.Bm.good.wav
# ffmpeg -ss 7221.9 -t 4.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:00:21.9.Bm.good.wav
# ffmpeg -ss 7285.4 -t 9.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:01:25.4.Bm.good.wav
# ffmpeg -ss 7413.0 -t 5.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:03:33.0.Bm.good.wav
# ffmpeg -ss 7602.1 -t 8.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:06:42.1.Bm.good.wav
# ffmpeg -ss 7665.6 -t 5.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:07:45.6.Bm.good.wav
# ffmpeg -ss 7740.6 -t 5.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:09:00.6.Bm.good.wav
# ffmpeg -ss 7858.9 -t 4.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:10:58.9.Bm.good.wav
# ffmpeg -ss 7980.4 -t 4.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:13:00.4.Bm.poor.wav
# ffmpeg -ss 8165.3 -t 9.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:16:05.3.Bm.good.wav
# ffmpeg -ss 8237.9 -t 5.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:17:17.9.Bm.good.wav
# ffmpeg -ss 8293.1 -t 9.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:18:13.1.Bm.good.wav
# ffmpeg -ss 8361.6 -t 5.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:19:21.6.Bm.good.wav
# ffmpeg -ss 8422.2 -t 6.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:20:22.2.Bm.good.wav
# ffmpeg -ss 8434.0 -t 5.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:20:34.0.Bm.good.wav
# ffmpeg -ss 8599.1 -t 7.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:23:19.1.Bm.good.wav
# ffmpeg -ss 8627.8 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:23:47.8.Bm.poor.wav
# ffmpeg -ss 8662.3 -t 3.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:24:22.3.Bm.good.wav
# ffmpeg -ss 8709.7 -t 8.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:25:09.7.Bm.good.wav
# ffmpeg -ss 8975.4 -t 4.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:29:35.4.Bm.good.wav
# ffmpeg -ss 9022.2 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:30:22.2.Bm.good.wav
# ffmpeg -ss 9139.5 -t 4.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:32:19.5.Bm.good.wav
# ffmpeg -ss 9195.4 -t 6.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:33:15.4.Bm.good.wav
# ffmpeg -ss 9365.3 -t 8.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:36:05.3.Bm.good.wav
# ffmpeg -ss 9433.1 -t 5.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:37:13.1.Bm.good.wav
# ffmpeg -ss 9503.2 -t 6.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:38:23.2.Bm.good.wav
# ffmpeg -ss 9566.3 -t 5.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:39:26.3.Bm.good.wav
# ffmpeg -ss 9627.6 -t 5.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:40:27.6.Bm.good.wav
# ffmpeg -ss 9675.6 -t 6.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:41:15.6.Bm.good.wav
# ffmpeg -ss 9694.1 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:41:34.1.Bm.good.wav
# ffmpeg -ss 9758.7 -t 5.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:42:38.7.Bm.good.wav
# ffmpeg -ss 9819.6 -t 3.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:43:39.6.Bm.good.wav
# ffmpeg -ss 9880.3 -t 4.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:44:40.3.Bm.good.wav
# ffmpeg -ss 9890.9 -t 6.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:44:50.9.Bm.good.wav
# ffmpeg -ss 10164.7 -t 5.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:49:24.7.Bm.good.wav
# ffmpeg -ss 10229.3 -t 4.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:50:29.3.Bm.good.wav
# ffmpeg -ss 10298.9 -t 7.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:51:38.9.Bm.good.wav
# ffmpeg -ss 10493.0 -t 5.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:54:53.0.Bm.good.wav
# ffmpeg -ss 10553.2 -t 4.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:55:53.2.Bm.good.wav
# ffmpeg -ss 10563.3 -t 5.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T02:56:03.3.Bm.good.wav
# ffmpeg -ss 10871.3 -t 3.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:01:11.3.Bm.good.wav
# ffmpeg -ss 10939.3 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:02:19.3.Bm.good.wav
# ffmpeg -ss 11017.1 -t 4.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:03:37.1.Bm.good.wav
# ffmpeg -ss 11149.2 -t 5.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:05:49.2.Bm.good.wav
# ffmpeg -ss 11210.0 -t 4.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:06:50.0.Bm.good.wav
# ffmpeg -ss 11272.0 -t 3.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:07:52.0.Bm.good.wav
# ffmpeg -ss 11281.0 -t 4.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:08:01.0.Bm.good.wav
# ffmpeg -ss 11437.8 -t 6.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:10:37.8.Bm.good.wav
# ffmpeg -ss 11481.5 -t 1.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:11:21.5.Bm.good.wav
# ffmpeg -ss 11503.2 -t 5.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:11:43.2.Bm.good.wav
# ffmpeg -ss 11563.1 -t 4.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:12:43.1.Bm.good.wav
# ffmpeg -ss 11702.7 -t 4.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:15:02.7.Bm.good.wav
# ffmpeg -ss 11724.7 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:15:24.7.Bm.good.wav
# ffmpeg -ss 11784.9 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:16:24.9.Bm.good.wav
# ffmpeg -ss 11840.6 -t 7.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:17:20.6.Bm.good.wav
# ffmpeg -ss 11902.2 -t 4.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:18:22.2.Bm.good.wav
# ffmpeg -ss 11912.7 -t 4.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:18:32.7.Bm.good.wav
# ffmpeg -ss 12145.5 -t 3.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:22:25.5.Bm.poor.wav
# ffmpeg -ss 12277.1 -t 5.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:24:37.1.Bm.poor.wav
# ffmpeg -ss 12344.5 -t 3.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:25:44.5.Bm.good.wav
# ffmpeg -ss 12410.1 -t 3.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:26:50.1.Bm.good.wav
# ffmpeg -ss 12477.8 -t 3.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:27:57.8.Bm.good.wav
# ffmpeg -ss 12737.9 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:32:17.9.Bm.good.wav
# ffmpeg -ss 12799.8 -t 4.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:33:19.8.Bm.good.wav
# ffmpeg -ss 12854.3 -t 5.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:34:14.3.Bm.poor.wav
# ffmpeg -ss 12923.1 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:35:23.1.Bm.good.wav
# ffmpeg -ss 12933.3 -t 4.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:35:33.3.Bm.good.wav
# ffmpeg -ss 13197.9 -t 2.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:39:57.9.Bm.poor.wav
# ffmpeg -ss 13271.1 -t 2.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:41:11.1.Bm.poor.wav
# ffmpeg -ss 13332.7 -t 4.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:42:12.7.Bm.good.wav
# ffmpeg -ss 13394.7 -t 5.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:43:14.7.Bm.good.wav
# ffmpeg -ss 13406.1 -t 4.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:43:26.1.Bm.good.wav
# ffmpeg -ss 13790.9 -t 3.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:49:50.9.Bm.good.wav
# ffmpeg -ss 13854.5 -t 4.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:50:54.5.Bm.good.wav
# ffmpeg -ss 13920.2 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:52:00.2.Bm.good.wav
# ffmpeg -ss 13995.3 -t 5.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:53:15.3.Bm.poor.wav
# ffmpeg -ss 14063.5 -t 3.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:54:23.5.Bm.good.wav
# ffmpeg -ss 14073.7 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T03:54:33.7.Bm.poor.wav
# ffmpeg -ss 15405.0 -t 7.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T04:16:45.0.Bm.good.wav
# ffmpeg -ss 15471.5 -t 4.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T04:17:51.5.Bm.good.wav
# ffmpeg -ss 15546.4 -t 7.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T04:19:06.4.Bm.good.wav
# ffmpeg -ss 15615.7 -t 3.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T04:20:15.7.Bm.good.wav
# ffmpeg -ss 15626.5 -t 4.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T04:20:26.5.Bm.poor.wav
# ffmpeg -ss 18292.9 -t 5.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:04:52.9.Bm.good.wav
# ffmpeg -ss 18434.1 -t 4.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:07:14.1.Bm.good.wav
# ffmpeg -ss 18446.5 -t 1.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:07:26.5.Bm.poor.wav
# ffmpeg -ss 19526.2 -t 6.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:25:26.2.Bm.good.wav
# ffmpeg -ss 19589.6 -t 4.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:26:29.6.Bm.good.wav
# ffmpeg -ss 19598.3 -t 4.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:26:38.3.Bm.good.wav
# ffmpeg -ss 19985.5 -t 9.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:33:05.5.Bm.good.wav
# ffmpeg -ss 20049.8 -t 5.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:34:09.8.Bm.good.wav
# ffmpeg -ss 20311.4 -t 1.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:38:31.4.Bm.good.wav
# ffmpeg -ss 20316.8 -t 5.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:38:36.8.Bm.good.wav
# ffmpeg -ss 20427.8 -t 2.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T05:40:27.8.Bm.poor.wav
# ffmpeg -ss 21646.3 -t 4.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:00:46.3.Bm.good.wav
# ffmpeg -ss 21657.2 -t 2.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:00:57.2.Bm.good.wav
# ffmpeg -ss 22077.2 -t 3.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:07:57.2.Bm.good.wav
# ffmpeg -ss 22128.3 -t 4.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:08:48.3.Bm.good.wav
# ffmpeg -ss 22143.6 -t 12.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:09:03.6.Bm.good.wav
# ffmpeg -ss 22209.8 -t 5.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:10:09.8.Bm.good.wav
# ffmpeg -ss 22272.6 -t 2.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:11:12.6.Bm.poor.wav
# ffmpeg -ss 22337.3 -t 5.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:12:17.3.Bm.good.wav
# ffmpeg -ss 22347.0 -t 3.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:12:27.0.Bm.good.wav
# ffmpeg -ss 22499.9 -t 4.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:14:59.9.Bm.good.wav
# ffmpeg -ss 22514.9 -t 11.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:15:14.9.Bm.good.wav
# ffmpeg -ss 22574.9 -t 2.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:16:14.9.Bm.good.wav
# ffmpeg -ss 22582.9 -t 3.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:16:22.9.Bm.good.wav
# ffmpeg -ss 22716.0 -t 6.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:18:36.0.Bm.good.wav
# ffmpeg -ss 22787.5 -t 7.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:19:47.5.Bm.good.wav
# ffmpeg -ss 22856.9 -t 5.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:20:56.9.Bm.good.wav
# ffmpeg -ss 22929.2 -t 7.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:22:09.2.Bm.good.wav
# ffmpeg -ss 22994.5 -t 4.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:23:14.5.Bm.good.wav
# ffmpeg -ss 23005.2 -t 5.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:23:25.2.Bm.good.wav
# ffmpeg -ss 23179.6 -t 3.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:26:19.6.Bm.good.wav
# ffmpeg -ss 23190.7 -t 14.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:26:30.7.Bm.good.wav
# ffmpeg -ss 23261.2 -t 4.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:27:41.2.Bm.good.wav
# ffmpeg -ss 24560.8 -t 9.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:49:20.8.Bm.good.wav
# ffmpeg -ss 24626.6 -t 5.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:50:26.6.Bm.good.wav
# ffmpeg -ss 24637.0 -t 6.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:50:37.0.Bm.good.wav
# ffmpeg -ss 24789.4 -t 13.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:53:09.4.Bm.good.wav
# ffmpeg -ss 24857.9 -t 6.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:54:17.9.Bm.good.wav
# ffmpeg -ss 24930.9 -t 6.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:55:30.9.Bm.good.wav
# ffmpeg -ss 25056.3 -t 2.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:57:36.3.Bm.good.wav
# ffmpeg -ss 25070.2 -t 8.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:57:50.2.Bm.good.wav
# ffmpeg -ss 25125.4 -t 7.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:58:45.4.Bm.good.wav
# ffmpeg -ss 25138.5 -t 5.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T06:58:58.5.Bm.good.wav
# ffmpeg -ss 25203.5 -t 17.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:00:03.5.Bm.good.wav
# ffmpeg -ss 25285.5 -t 8.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:01:25.5.Bm.good.wav
# ffmpeg -ss 25351.9 -t 6.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:02:31.9.Bm.good.wav
# ffmpeg -ss 25433.9 -t 14.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:03:53.9.Bm.good.wav
# ffmpeg -ss 25572.0 -t 2.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:06:12.0.Bm.good.wav
# ffmpeg -ss 25640.6 -t 4.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:07:20.6.Bm.good.wav
# ffmpeg -ss 25840.2 -t 14.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:10:40.2.Bm.good.wav
# ffmpeg -ss 25909.6 -t 5.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:11:49.6.Bm.good.wav
# ffmpeg -ss 26012.1 -t 12.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:13:32.1.Bm.good.wav
# ffmpeg -ss 26217.5 -t 15.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:16:57.5.Bm.good.wav
# ffmpeg -ss 26287.0 -t 7.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:18:07.0.Bm.good.wav
# ffmpeg -ss 26373.9 -t 12.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:19:33.9.Bm.good.wav
# ffmpeg -ss 26540.1 -t 6.8 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:22:20.1.Bm.good.wav
# ffmpeg -ss 26614.8 -t 10.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:23:34.8.Bm.good.wav
# ffmpeg -ss 26683.4 -t 6.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:24:43.4.Bm.good.wav
# ffmpeg -ss 26747.5 -t 7.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:25:47.5.Bm.good.wav
# ffmpeg -ss 26759.0 -t 7.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:25:59.0.Bm.good.wav
# ffmpeg -ss 27392.7 -t 5.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:36:32.7.Bm.good.wav
# ffmpeg -ss 27590.9 -t 9.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:39:50.9.Bm.good.wav
# ffmpeg -ss 27658.6 -t 7.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:40:58.6.Bm.good.wav
# ffmpeg -ss 27774.4 -t 11.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T07:42:54.4.Bm.good.wav
# ffmpeg -ss 29737.9 -t 14.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:15:37.9.Bm.good.wav
# ffmpeg -ss 29806.8 -t 10.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:16:46.8.Bm.good.wav
# ffmpeg -ss 29818.5 -t 8.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:16:58.5.Bm.good.wav
# ffmpeg -ss 29925.2 -t 3.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:18:45.2.Bm.good.wav
# ffmpeg -ss 29995.8 -t 5.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:19:55.8.Bm.good.wav
# ffmpeg -ss 30008.0 -t 2.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:20:08.0.Bm.good.wav
# ffmpeg -ss 30065.2 -t 7.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:21:05.2.Bm.good.wav
# ffmpeg -ss 30287.7 -t 9.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:24:47.7.Bm.good.wav
# ffmpeg -ss 30358.0 -t 7.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:25:58.0.Bm.good.wav
# ffmpeg -ss 30420.6 -t 9.1 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:27:00.6.Bm.good.wav
# ffmpeg -ss 30432.2 -t 8.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:27:12.2.Bm.good.wav
# ffmpeg -ss 30555.9 -t 14.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:29:15.9.Bm.good.wav
# ffmpeg -ss 30625.0 -t 8.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:30:25.0.Bm.good.wav
# ffmpeg -ss 30694.9 -t 13.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:31:34.9.Bm.good.wav
# ffmpeg -ss 30876.8 -t 15.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:34:36.8.Bm.good.wav
# ffmpeg -ss 30945.6 -t 9.2 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:35:45.6.Bm.good.wav
# ffmpeg -ss 31025.3 -t 15.3 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:37:05.3.Bm.good.wav
# ffmpeg -ss 31093.2 -t 8.4 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:38:13.2.Bm.good.wav
# ffmpeg -ss 31104.9 -t 8.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:38:24.9.Bm.good.wav
# ffmpeg -ss 31202.3 -t 6.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:40:02.3.Bm.good.wav
# ffmpeg -ss 31275.2 -t 3.6 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:41:15.2.Bm.good.wav
# ffmpeg -ss 31284.0 -t 15.5 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:41:24.0.Bm.good.wav
# ffmpeg -ss 31350.1 -t 10.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:42:30.1.Bm.good.wav
# ffmpeg -ss 31433.1 -t 12.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T08:43:53.1.Bm.good.wav
# ffmpeg -ss 45415.0 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T12:36:55.0.Bm.good.wav
# ffmpeg -ss 45425.2 -t 2.7 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T12:37:05.2.Bm.poor.wav
# ffmpeg -ss 65430.2 -t 4.0 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T18:10:30.2.Bm.poor.wav
# ffmpeg -ss 76475.0 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T21:14:35.0.Bm.good.wav
# ffmpeg -ss 76538.0 -t 3.9 -i wav/train/WAT_HZ_01_160217_000000.df100.x.wav read/Bm/WAT_HZ_2016-02-17T21:15:38.0.Bm.good.wav
# ffmpeg -i wav/train/HAT_A_02_121023_142845.d100.x.wav 2>&1 | grep "Duration"| cut -d ' ' -f 4 | sed s/,// | awk '{ split($1, A, ":"); print 3600*A[1] + 60*A[2] + A[3] }'
# ffmpeg -ss 34377.2 -t 3.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T00:01:42.2.Bm.poor.wav
# ffmpeg -ss 34428.4 -t 3.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T00:02:33.4.Bm.poor.wav
# ffmpeg -ss 37956.4 -t 3.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T01:01:21.4.Bm.poor.wav
# ffmpeg -ss 38022.2 -t 2.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T01:02:27.2.Bm.poor.wav
# ffmpeg -ss 38090.4 -t 7.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T01:03:35.4.Bm.poor.wav
# ffmpeg -ss 38933.1 -t 2.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T01:17:38.1.Bm.poor.wav
# ffmpeg -ss 45599.7 -t 3.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T03:08:44.7.Bm.poor.wav
# ffmpeg -ss 46478.2 -t 3.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T03:23:23.2.Bm.poor.wav
# ffmpeg -ss 47063.8 -t 4.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T03:33:08.8.Bm.poor.wav
# ffmpeg -ss 47135.6 -t 4.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T03:34:20.6.Bm.poor.wav
# ffmpeg -ss 47269.5 -t 4.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T03:36:34.5.Bm.poor.wav
# ffmpeg -ss 48144.1 -t 4.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T03:51:09.1.Bm.poor.wav
# ffmpeg -ss 48483.3 -t 5.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T03:56:48.3.Bm.poor.wav
# ffmpeg -ss 48763.9 -t 3.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:01:28.9.Bm.poor.wav
# ffmpeg -ss 48829.3 -t 5.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:02:34.3.Bm.poor.wav
# ffmpeg -ss 48971.6 -t 4.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:04:56.6.Bm.poor.wav
# ffmpeg -ss 49033.3 -t 7.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:05:58.3.Bm.poor.wav
# ffmpeg -ss 49103.5 -t 5.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:07:08.5.Bm.poor.wav
# ffmpeg -ss 49170.3 -t 7.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:08:15.3.Bm.poor.wav
# ffmpeg -ss 49241.2 -t 3.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:09:26.2.Bm.poor.wav
# ffmpeg -ss 49308.2 -t 5.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:10:33.2.Bm.poor.wav
# ffmpeg -ss 49373.1 -t 5.0 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:11:38.1.Bm.poor.wav
# ffmpeg -ss 49857.8 -t 4.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:19:42.8.Bm.poor.wav
# ffmpeg -ss 49926.7 -t 4.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:20:51.7.Bm.poor.wav
# ffmpeg -ss 49998.1 -t 7.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:22:03.1.Bm.poor.wav
# ffmpeg -ss 50073.6 -t 4.3 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:23:18.6.Bm.poor.wav
# ffmpeg -ss 50139.3 -t 8.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:24:24.3.Bm.poor.wav
# ffmpeg -ss 50212.0 -t 9.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:25:37.0.Bm.poor.wav
# ffmpeg -ss 50279.7 -t 9.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:26:44.7.Bm.good.wav
# ffmpeg -ss 50344.0 -t 4.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:27:49.0.Bm.poor.wav
# ffmpeg -ss 50549.0 -t 6.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:31:14.0.Bm.poor.wav
# ffmpeg -ss 50685.6 -t 7.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:33:30.6.Bm.poor.wav
# ffmpeg -ss 50757.8 -t 5.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:34:42.8.Bm.poor.wav
# ffmpeg -ss 50828.0 -t 7.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:35:53.0.Bm.poor.wav
# ffmpeg -ss 50899.1 -t 4.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:37:04.1.Bm.poor.wav
# ffmpeg -ss 50965.9 -t 7.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T04:38:10.9.Bm.poor.wav
# ffmpeg -ss 52709.4 -t 8.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T05:07:14.4.Bm.poor.wav
# ffmpeg -ss 52784.6 -t 5.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T05:08:29.6.Bm.poor.wav
# ffmpeg -ss 53571.6 -t 5.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T05:21:36.6.Bm.poor.wav
# ffmpeg -ss 55855.8 -t 1.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T05:59:40.8.Bm.poor.wav
# ffmpeg -ss 63539.0 -t 8.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T08:07:44.0.Bm.poor.wav
# ffmpeg -ss 63893.1 -t 5.3 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T08:13:38.1.Bm.poor.wav
# ffmpeg -ss 64532.1 -t 5.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T08:24:17.1.Bm.poor.wav
# ffmpeg -ss 64734.7 -t 6.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T08:27:39.7.Bm.good.wav
# ffmpeg -ss 64883.5 -t 4.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T08:30:08.5.Bm.poor.wav
# ffmpeg -ss 65086.7 -t 2.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T08:33:31.7.Bm.poor.wav
# ffmpeg -ss 67386.3 -t 8.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T09:11:51.3.Bm.poor.wav
# ffmpeg -ss 67455.4 -t 7.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T09:13:00.4.Bm.good.wav
# ffmpeg -ss 68198.6 -t 1.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T09:25:23.6.Bm.poor.wav
# ffmpeg -ss 68788.6 -t 2.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T09:35:13.6.Bm.poor.wav
# ffmpeg -ss 69930.6 -t 3.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T09:54:15.6.Bm.poor.wav
# ffmpeg -ss 70000.2 -t 5.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T09:55:25.2.Bm.poor.wav
# ffmpeg -ss 70071.6 -t 3.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T09:56:36.6.Bm.poor.wav
# ffmpeg -ss 70836.4 -t 3.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T10:09:21.4.Bm.poor.wav
# ffmpeg -ss 71352.4 -t 3.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T10:17:57.4.Bm.poor.wav
# ffmpeg -ss 73182.2 -t 5.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T10:48:27.2.Bm.poor.wav
# ffmpeg -ss 77992.0 -t 3.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:08:37.0.Bm.poor.wav
# ffmpeg -ss 78107.9 -t 7.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:10:32.9.Bm.poor.wav
# ffmpeg -ss 78391.8 -t 7.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:15:16.8.Bm.good.wav
# ffmpeg -ss 78615.1 -t 8.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:19:00.1.Bm.good.wav
# ffmpeg -ss 78677.7 -t 6.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:20:02.7.Bm.poor.wav
# ffmpeg -ss 78927.2 -t 4.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:24:12.2.Bm.poor.wav
# ffmpeg -ss 79654.8 -t 5.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:36:19.8.Bm.poor.wav
# ffmpeg -ss 80268.0 -t 7.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:46:33.0.Bm.good.wav
# ffmpeg -ss 80671.3 -t 6.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:53:16.3.Bm.poor.wav
# ffmpeg -ss 80771.9 -t 4.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:54:56.9.Bm.poor.wav
# ffmpeg -ss 80915.9 -t 4.0 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T12:57:20.9.Bm.poor.wav
# ffmpeg -ss 81180.1 -t 11.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:01:45.1.Bm.good.wav
# ffmpeg -ss 81245.1 -t 8.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:02:50.1.Bm.good.wav
# ffmpeg -ss 81639.0 -t 2.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:09:24.0.Bm.poor.wav
# ffmpeg -ss 81699.5 -t 5.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:10:24.5.Bm.poor.wav
# ffmpeg -ss 83091.0 -t 4.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:33:36.0.Bm.poor.wav
# ffmpeg -ss 83120.4 -t 4.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:34:05.4.Bm.poor.wav
# ffmpeg -ss 83447.5 -t 6.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:39:32.5.Bm.poor.wav
# ffmpeg -ss 83651.6 -t 8.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:42:56.6.Bm.poor.wav
# ffmpeg -ss 84168.8 -t 8.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:51:33.8.Bm.poor.wav
# ffmpeg -ss 84221.6 -t 2.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T13:52:26.6.Bm.poor.wav
# ffmpeg -ss 85205.2 -t 2.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T14:08:50.2.Bm.poor.wav
# ffmpeg -ss 85617.4 -t 1.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T14:15:42.4.Bm.poor.wav
# ffmpeg -ss 86217.3 -t 5.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T14:25:42.3.Bm.poor.wav
# ffmpeg -ss 86257.1 -t 3.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T14:26:22.1.Bm.poor.wav
# ffmpeg -ss 86569.2 -t 4.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T14:31:34.2.Bm.poor.wav
# ffmpeg -ss 88099.4 -t 3.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T14:57:04.4.Bm.poor.wav
# ffmpeg -ss 94744.1 -t 2.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T16:47:49.1.Bm.poor.wav
# ffmpeg -ss 100642.8 -t 3.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:26:07.8.Bm.poor.wav
# ffmpeg -ss 100658.5 -t 2.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:26:23.5.Bm.poor.wav
# ffmpeg -ss 100673.2 -t 1.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:26:38.2.Bm.poor.wav
# ffmpeg -ss 101358.9 -t 3.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:38:03.9.Bm.poor.wav
# ffmpeg -ss 101561.2 -t 6.3 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:41:26.2.Bm.good.wav
# ffmpeg -ss 101631.3 -t 4.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:42:36.3.Bm.poor.wav
# ffmpeg -ss 102207.0 -t 3.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:52:12.0.Bm.poor.wav
# ffmpeg -ss 102276.5 -t 4.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:53:21.5.Bm.poor.wav
# ffmpeg -ss 102575.1 -t 6.0 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:58:20.1.Bm.poor.wav
# ffmpeg -ss 102638.7 -t 8.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T18:59:23.7.Bm.poor.wav
# ffmpeg -ss 102840.8 -t 4.8 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:02:45.8.Bm.poor.wav
# ffmpeg -ss 102981.4 -t 7.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:05:06.4.Bm.poor.wav
# ffmpeg -ss 103282.0 -t 4.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:10:07.0.Bm.poor.wav
# ffmpeg -ss 103471.5 -t 3.0 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:13:16.5.Bm.poor.wav
# ffmpeg -ss 104017.6 -t 4.4 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:22:22.6.Bm.poor.wav
# ffmpeg -ss 105100.9 -t 2.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:40:25.9.Bm.poor.wav
# ffmpeg -ss 105210.8 -t 3.3 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:42:15.8.Bm.poor.wav
# ffmpeg -ss 106176.1 -t 4.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:58:21.1.Bm.poor.wav
# ffmpeg -ss 106239.1 -t 2.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T19:59:24.1.Bm.poor.wav
# ffmpeg -ss 106298.4 -t 5.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T20:00:23.4.Bm.poor.wav
# ffmpeg -ss 112493.5 -t 2.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T21:43:38.5.Bm.poor.wav
# ffmpeg -ss 119839.1 -t 6.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-24T23:46:04.1.Bm.poor.wav
# ffmpeg -ss 121070.8 -t 2.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T00:06:35.8.Bm.poor.wav
# ffmpeg -ss 121483.8 -t 4.0 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T00:13:28.8.Bm.poor.wav
# ffmpeg -ss 121897.4 -t 7.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T00:20:22.4.Bm.poor.wav
# ffmpeg -ss 122121.5 -t 5.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T00:24:06.5.Bm.poor.wav
# ffmpeg -ss 122449.6 -t 6.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T00:29:34.6.Bm.poor.wav
# ffmpeg -ss 122518.0 -t 5.0 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T00:30:43.0.Bm.poor.wav
# ffmpeg -ss 123071.1 -t 7.0 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T00:39:56.1.Bm.poor.wav
# ffmpeg -ss 124156.9 -t 7.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T00:58:01.9.Bm.poor.wav
# ffmpeg -ss 124602.6 -t 7.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:05:27.6.Bm.poor.wav
# ffmpeg -ss 125032.3 -t 8.0 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:12:37.3.Bm.poor.wav
# ffmpeg -ss 125106.4 -t 4.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:13:51.4.Bm.poor.wav
# ffmpeg -ss 125623.1 -t 2.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:22:28.1.Bm.poor.wav
# ffmpeg -ss 127288.5 -t 2.7 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:50:13.5.Bm.poor.wav
# ffmpeg -ss 127364.1 -t 4.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:51:29.1.Bm.poor.wav
# ffmpeg -ss 127431.9 -t 6.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:52:36.9.Bm.poor.wav
# ffmpeg -ss 127502.4 -t 2.9 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:53:47.4.Bm.poor.wav
# ffmpeg -ss 127631.4 -t 7.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:55:56.4.Bm.poor.wav
# ffmpeg -ss 127699.7 -t 5.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:57:04.7.Bm.poor.wav
# ffmpeg -ss 127851.3 -t 5.5 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T01:59:36.3.Bm.poor.wav
# ffmpeg -ss 128643.9 -t 4.3 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T02:12:48.9.Bm.poor.wav
# ffmpeg -ss 130005.0 -t 3.1 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T02:35:30.0.Bm.poor.wav
# ffmpeg -ss 135706.2 -t 5.6 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T04:10:31.2.Bm.poor.wav
# ffmpeg -ss 136067.0 -t 7.2 -i wav/train/HAT_A_02_121023_142845.d100.x.wav read/Bm/HAT_A_2012-10-25T04:16:32.0.Bm.poor.wav
# ...
# ffmpeg -ss 35372.5 -t 5.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T09:49:32.5.Bm.poor.wav
# ffmpeg -ss 35394.1 -t 5.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T09:49:54.1.Bm.poor.wav
# ffmpeg -ss 36748.4 -t 3.2 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T10:12:28.4.Bm.poor.wav
# ffmpeg -ss 36878.4 -t 2.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T10:14:38.4.Bm.poor.wav
# ffmpeg -ss 37089.8 -t 2.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T10:18:09.8.Bm.poor.wav
# ffmpeg -ss 37157.1 -t 2.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T10:19:17.1.Bm.poor.wav
# ffmpeg -ss 37657.4 -t 2.2 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T10:27:37.4.Bm.poor.wav
# ffmpeg -ss 42564.9 -t 7.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T11:49:24.9.Bm.good.wav
# ffmpeg -ss 47691.4 -t 3.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T13:14:51.4.Bm.good.wav
# ffmpeg -ss 59086.6 -t 4.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T16:24:46.6.Bm.poor.wav
# ffmpeg -ss 60337.3 -t 3.7 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T16:45:37.3.Bm.poor.wav
# ffmpeg -ss 61992.7 -t 1.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T17:13:12.7.Bm.good.wav
# ffmpeg -ss 65947.0 -t 6.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T18:19:07.0.Bm.good.wav
# ffmpeg -ss 67412.1 -t 6.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T18:43:32.1.Bm.poor.wav
# ffmpeg -ss 68257.8 -t 7.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T18:57:37.8.Bm.poor.wav
# ffmpeg -ss 68472.6 -t 4.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:01:12.6.Bm.poor.wav
# ffmpeg -ss 69425.0 -t 4.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:17:05.0.Bm.poor.wav
# ffmpeg -ss 70023.7 -t 1.7 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:27:03.7.Bm.poor.wav
# ffmpeg -ss 70818.2 -t 4.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:40:18.2.Bm.poor.wav
# ffmpeg -ss 70883.3 -t 2.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:41:23.3.Bm.poor.wav
# ffmpeg -ss 70985.7 -t 1.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:43:05.7.Bm.poor.wav
# ffmpeg -ss 70993.3 -t 2.2 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:43:13.3.Bm.poor.wav
# ffmpeg -ss 71222.2 -t 2.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:47:02.2.Bm.poor.wav
# ffmpeg -ss 71267.6 -t 3.2 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:47:47.6.Bm.good.wav
# ffmpeg -ss 71340.2 -t 3.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:49:00.2.Bm.poor.wav
# ffmpeg -ss 71411.1 -t 3.2 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:50:11.1.Bm.poor.wav
# ffmpeg -ss 71780.4 -t 3.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T19:56:20.4.Bm.poor.wav
# ffmpeg -ss 72058.3 -t 5.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T20:00:58.3.Bm.poor.wav
# ffmpeg -ss 72748.5 -t 1.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T20:12:28.5.Bm.poor.wav
# ffmpeg -ss 72773.5 -t 5.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T20:12:53.5.Bm.poor.wav
# ffmpeg -ss 73330.2 -t 6.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T20:22:10.2.Bm.poor.wav
# ffmpeg -ss 73817.8 -t 5.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T20:30:17.8.Bm.poor.wav
# ffmpeg -ss 74859.3 -t 6.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T20:47:39.3.Bm.poor.wav
# ffmpeg -ss 76253.4 -t 2.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:10:53.4.Bm.poor.wav
# ffmpeg -ss 76867.2 -t 2.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:21:07.2.Bm.poor.wav
# ffmpeg -ss 76941.0 -t 2.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:22:21.0.Bm.poor.wav
# ffmpeg -ss 77590.2 -t 9.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:33:10.2.Bm.poor.wav
# ffmpeg -ss 77960.3 -t 6.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:39:20.3.Bm.poor.wav
# ffmpeg -ss 78606.0 -t 6.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:50:06.0.Bm.poor.wav
# ffmpeg -ss 78886.3 -t 6.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:54:46.3.Bm.poor.wav
# ffmpeg -ss 78969.6 -t 5.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:56:09.6.Bm.poor.wav
# ffmpeg -ss 79054.9 -t 3.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T21:57:34.9.Bm.poor.wav
# ffmpeg -ss 81465.0 -t 5.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T22:37:45.0.Bm.poor.wav
# ffmpeg -ss 81740.2 -t 5.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-21T22:42:20.2.Bm.poor.wav
# ffmpeg -ss 92790.8 -t 7.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T01:46:30.8.Bm.poor.wav
# ffmpeg -ss 96553.8 -t 3.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T02:49:13.8.Bm.poor.wav
# ffmpeg -ss 97345.6 -t 4.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:02:25.6.Bm.poor.wav
# ffmpeg -ss 97654.2 -t 4.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:07:34.2.Bm.good.wav
# ffmpeg -ss 97944.1 -t 5.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:12:24.1.Bm.good.wav
# ffmpeg -ss 98266.3 -t 3.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:17:46.3.Bm.poor.wav
# ffmpeg -ss 98398.2 -t 9.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:19:58.2.Bm.good.wav
# ffmpeg -ss 98473.3 -t 6.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:21:13.3.Bm.good.wav
# ffmpeg -ss 98693.8 -t 2.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:24:53.8.Bm.poor.wav
# ffmpeg -ss 98766.0 -t 3.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:26:06.0.Bm.poor.wav
# ffmpeg -ss 98873.5 -t 5.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:27:53.5.Bm.poor.wav
# ffmpeg -ss 98945.6 -t 1.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:29:05.6.Bm.poor.wav
# ffmpeg -ss 99235.0 -t 6.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:33:55.0.Bm.poor.wav
# ffmpeg -ss 99378.2 -t 6.2 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:36:18.2.Bm.poor.wav
# ffmpeg -ss 99447.4 -t 8.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:37:27.4.Bm.poor.wav
# ffmpeg -ss 99493.5 -t 3.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:38:13.5.Bm.poor.wav
# ffmpeg -ss 100342.2 -t 3.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T03:52:22.2.Bm.poor.wav
# ffmpeg -ss 101422.5 -t 4.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T04:10:22.5.Bm.poor.wav
# ffmpeg -ss 102947.4 -t 4.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T04:35:47.4.Bm.poor.wav
# ffmpeg -ss 103101.8 -t 2.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T04:38:21.8.Bm.poor.wav
# ffmpeg -ss 103839.6 -t 3.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T04:50:39.6.Bm.poor.wav
# ffmpeg -ss 104757.8 -t 3.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T05:05:57.8.Bm.poor.wav
# ffmpeg -ss 106079.4 -t 4.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T05:27:59.4.Bm.poor.wav
# ffmpeg -ss 109105.3 -t 4.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T06:18:25.3.Bm.poor.wav
# ffmpeg -ss 109229.0 -t 9.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T06:20:29.0.Bm.poor.wav
# ffmpeg -ss 109701.8 -t 4.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T06:28:21.8.Bm.poor.wav
# ffmpeg -ss 115671.6 -t 3.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T08:07:51.6.Bm.poor.wav
# ffmpeg -ss 117306.3 -t 4.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T08:35:06.3.Bm.poor.wav
# ffmpeg -ss 119372.2 -t 1.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:09:32.2.Bm.poor.wav
# ffmpeg -ss 119383.5 -t 2.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:09:43.5.Bm.poor.wav
# ffmpeg -ss 119469.8 -t 7.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:11:09.8.Bm.poor.wav
# ffmpeg -ss 119752.2 -t 5.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:15:52.2.Bm.poor.wav
# ffmpeg -ss 120029.4 -t 1.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:20:29.4.Bm.poor.wav
# ffmpeg -ss 120361.1 -t 4.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:26:01.1.Bm.poor.wav
# ffmpeg -ss 120676.3 -t 4.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:31:16.3.Bm.poor.wav
# ffmpeg -ss 120900.9 -t 4.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:35:00.9.Bm.good.wav
# ffmpeg -ss 121021.8 -t 1.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:37:01.8.Bm.poor.wav
# ffmpeg -ss 121063.9 -t 1.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:37:43.9.Bm.poor.wav
# ffmpeg -ss 121222.8 -t 3.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:40:22.8.Bm.good.wav
# ffmpeg -ss 121445.7 -t 2.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:44:05.7.Bm.poor.wav
# ffmpeg -ss 121676.3 -t 2.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:47:56.3.Bm.poor.wav
# ffmpeg -ss 121804.9 -t 1.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T09:50:04.9.Bm.poor.wav
# ffmpeg -ss 123082.9 -t 2.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T10:11:22.9.Bm.poor.wav
# ffmpeg -ss 123123.8 -t 4.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T10:12:03.8.Bm.poor.wav
# ffmpeg -ss 123268.0 -t 6.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T10:14:28.0.Bm.poor.wav
# ffmpeg -ss 123769.7 -t 9.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T10:22:49.7.Bm.good.wav
# ffmpeg -ss 126320.0 -t 2.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T11:05:20.0.Bm.poor.wav
# ffmpeg -ss 128320.3 -t 4.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T11:38:40.3.Bm.poor.wav
# ffmpeg -ss 128643.6 -t 3.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T11:44:03.6.Bm.poor.wav
# ffmpeg -ss 129040.9 -t 2.2 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T11:50:40.9.Bm.poor.wav
# ffmpeg -ss 131974.3 -t 2.9 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T12:39:34.3.Bm.poor.wav
# ffmpeg -ss 133445.2 -t 4.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T13:04:05.2.Bm.good.wav
# ffmpeg -ss 133559.0 -t 3.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T13:05:59.0.Bm.good.wav
# ffmpeg -ss 133699.5 -t 3.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T13:08:19.5.Bm.good.wav
# ffmpeg -ss 147695.9 -t 3.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T17:01:35.9.Bm.poor.wav
# ffmpeg -ss 151397.1 -t 2.1 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T18:03:17.1.Bm.poor.wav
# ffmpeg -ss 159117.5 -t 3.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T20:11:57.5.Bm.good.wav
# ffmpeg -ss 162376.8 -t 3.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T21:06:16.8.Bm.poor.wav
# ffmpeg -ss 163784.5 -t 3.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T21:29:44.5.Bm.poor.wav
# ffmpeg -ss 164454.6 -t 5.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T21:40:54.6.Bm.good.wav
# ffmpeg -ss 165893.0 -t 4.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T22:04:53.0.Bm.poor.wav
# ffmpeg -ss 165976.1 -t 4.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T22:06:16.1.Bm.poor.wav
# ffmpeg -ss 166040.4 -t 3.2 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-22T22:07:20.4.Bm.poor.wav
# ffmpeg -ss 173420.9 -t 2.7 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T00:10:20.9.Bm.end.wav
# ffmpeg -ss 176575.5 -t 5.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:02:55.5.Bm.good.wav
# ffmpeg -ss 176598.8 -t 2.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:03:18.8.Bm.poor.wav
# ffmpeg -ss 176952.5 -t 5.5 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:09:12.5.Bm.good.wav
# ffmpeg -ss 176976.1 -t 1.7 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:09:36.1.Bm.poor.wav
# ffmpeg -ss 177136.5 -t 1.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:12:16.5.Bm.poor.wav
# ffmpeg -ss 177265.7 -t 5.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:14:25.7.Bm.good.wav
# ffmpeg -ss 177289.4 -t 1.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:14:49.4.Bm.poor.wav
# ffmpeg -ss 177462.3 -t 6.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:17:42.3.Bm.good.wav
# ffmpeg -ss 178151.1 -t 4.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:29:11.1.Bm.poor.wav
# ffmpeg -ss 178361.1 -t 2.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T01:32:41.1.Bm.poor.wav
# ffmpeg -ss 183821.0 -t 4.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T03:03:41.0.Bm.poor.wav
# ffmpeg -ss 184646.7 -t 6.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T03:17:26.7.Bm.good.wav
# ffmpeg -ss 184953.5 -t 5.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T03:22:33.5.Bm.good.wav
# ffmpeg -ss 185113.4 -t 4.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T03:25:13.4.Bm.poor.wav
# ffmpeg -ss 186248.1 -t 6.0 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T03:44:08.1.Bm.poor.wav
# ffmpeg -ss 186323.9 -t 4.4 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T03:45:23.9.Bm.poor.wav
# ffmpeg -ss 191067.2 -t 3.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T05:04:27.2.Bm.poor.wav
# ffmpeg -ss 193899.0 -t 3.3 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T05:51:39.0.Bm.poor.wav
# ffmpeg -ss 203653.8 -t 2.8 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T08:34:13.8.Bm.poor.wav
# ffmpeg -ss 208634.8 -t 3.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T09:57:14.8.Bm.poor.wav
# ffmpeg -ss 208926.1 -t 3.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T10:02:06.1.Bm.poor.wav
# ffmpeg -ss 209109.0 -t 3.7 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T10:05:09.0.Bm.poor.wav
# ffmpeg -ss 210108.5 -t 3.6 -i wav/train/HAT_A_02_121021_000000.d100.x.wav read/Bm/HAT_A_2012-10-23T10:21:48.5.Bm.poor.wav

# %%
import librosa
import util
import numpy as np
import sys
import os
import glob
import sh
import matplotlib.pyplot as plt


def padding_audio(data,fs,T):
    # Calculate target number of samples
    N_tar = int(fs * T)
    # Calculate number of zero samples to append
    shape = data.shape
    # Create the target shape
    N_pad = N_tar - shape[0]
#     print("Padding with %f seconds of silence" % float(N_pad/fs))
    shape = (N_pad,) + shape[1:]
    # Stack only if there is something to append
    if shape[0] > 0:
        if len(shape) > 1:
            return np.vstack((data,np.zeros(shape)))
        else:
            return np.hstack((data,np.zeros(shape)))
    else:
        return data




def read_audio(read_dir,sub_dirs,T_total,padding_dir,labels):
    for k, sub_dir in enumerate(sub_dirs):
        #print("label: %s" % (label))
#         print("sub_dir: %s" % (sub_dir))
        for i, f in enumerate(glob.glob(read_dir + os.sep+ sub_dir + os.sep +'*.wav')):               # for each WAV file

            wavFile = f
#             print wavFile
            waveFile_name = (os.path.splitext(wavFile)[0]).split(os.sep)[2]
#             print waveFile_name
            quality = util.splitext(waveFile_name)[2]
#             print quality
            # Read the wav file
            in_data, fs = librosa.load(wavFile)

            #print("fs is ",fs)
            #print("data is ", in_data)
            #print os.path.splitext(wavFile)[0]


            cmd = """ffmpeg -i """ + wavFile + """ 2>&1 | grep "Duration"| cut -d ' ' -f 4 | sed s/,// | awk '{ split($1, A, ":"); print 3600*A[1] + 60*A[2] + A[3] }'"""
            rs = sh.run(cmd, True)

            duration_in_wavFile = rs.stdout()
#             print("the duration of wavfile is ", duration_in_wavFile)
#             print type(duration_in_wavFile)

            if float(T_total) >= float(duration_in_wavFile):
                out_data = padding_audio(in_data,fs,T_total)

                # Save the output file
                for l in labels:
                    if quality == l:
                        out_wav = padding_dir +"/"+ l +"/"+ waveFile_name +".wav"
                    # if quality == "Eg":
                    #     out_wav = result_padding_dir +"/"+ eg_padding_dir +"/" +waveFile_name+".wav"

                    librosa.output.write_wav(out_wav, out_data, fs)


            else:
                int_num = int(float(duration_in_wavFile) / T_total)+1
                number = float(duration_in_wavFile) % T_total
#                 print number,int_num
                if number != 0:
                    T = T_total*int_num
                    out_data = padding_audio(in_data,fs,T)
                    for l in labels:
                        if quality == l:
                            out_wav = padding_dir +"/"+ l +"/"+ waveFile_name +".wav"
                        # if quality == "Eg":
                        #     out_wav = result_padding_dir +"/"+ eg_padding_dir +"/" +waveFile_name+".wav"

                        librosa.output.write_wav(out_wav, out_data, fs)




def cut_padding_audio(padding_dir,sub_dirs,T_total,redimension_dir,labels):
    for k, sub_padding in enumerate(sub_dirs):
        #print("label: %s" % (label))
#         print("sub_padding: %s" % (sub_padding))
        for i, f in enumerate(glob.glob(padding_dir + os.sep + sub_padding + os.sep+'*.wav')):               # for each WAV file

            wavFile = f
#             print wavFile
            waveFile_name = (os.path.splitext(wavFile)[0]).split(os.sep)[2]
            quality = util.splitext(waveFile_name)[2]
#             print quality

            cmd = """ffmpeg -i """ + wavFile + """ 2>&1 | grep "Duration"| cut -d ' ' -f 4 | sed s/,// | awk '{ split($1, A, ":"); print 3600*A[1] + 60*A[2] + A[3] }'"""
            rs = sh.run(cmd, True)

            duration_in_wavFile = rs.stdout()
#             print("the duration of wavfile is ", duration_in_wavFile)
            int_num = int(float(duration_in_wavFile) / float(T_total))-1
#             print int_num
            cut_point = np.linspace(0,T_total*int_num,int_num+1)
#             print cut_point
            if float(duration_in_wavFile) > float(T_total):
                for j in range(0, len(cut_point)):
#                     print str(cut_point[j])
                    for l in labels:

                        if quality == l:
                            number = np.random.randint(0,9)
                            if number>2:
                                path_name = redimension_dir+"/"+"train" +"/"+ l +"/"
                            else:
                                path_name = redimension_dir+"/"+"test" +"/"+ l +"/"
                        # if quality == "Eg":
                        #     path_name = result_redimension_dir +"/"+ eg_redimension_dir +"/"

                    cmd = "ffmpeg -ss " + str(cut_point[j]) + " -t " + str(T_total)+ " -i " + wavFile + " " + path_name + waveFile_name +"_"+ str(j) + ".wav"
                    sh.run(cmd)
            else:
                for l in labels:
                    if quality == l:
                        number = np.random.randint(0,9)
                        if number>2:
                            path_name = redimension_dir+"/"+"train" +"/"+ l +"/"
                        else:
                            path_name = redimension_dir+"/"+"test" +"/"+ l +"/"
                    # if quality == "Eg":
                    #     path_name = result_redimension_dir +"/"+ eg_redimension_dir +"/"

                cmd = "cp " + wavFile +" "+ path_name
                sh.run(cmd)

def clean(file_dir):
    for i, f in enumerate(glob.glob(file_dir + os.sep +'*')):
        # print f
        cmd = "rm -rf " + f  + "/*.wav"
        sh.run(cmd)



if __name__ == "__main__":

    # wav_dir = "result_eg"
    read_dir = "read"
    padding_dir = "padding"
    redimension_dir = "redimension"
    redimension__train_dir = "redimension/train"
    redimension__test_dir = "redimension/test"
    labels = []
    T_total = 4
    sub_dirs = []
    for i, f in enumerate(glob.glob(read_dir + os.sep +'*')):
        f = os.path.splitext(f)[0]
        sub_dirs.append(f.split(os.sep)[1])
        labels.append(f.split(os.sep)[1])
#     print labels

    clean(padding_dir)
    clean(redimension__train_dir)
    clean(redimension__test_dir)
    read_audio(read_dir,sub_dirs,T_total,padding_dir,labels)
    cut_padding_audio(padding_dir,sub_dirs,T_total,redimension_dir,labels)
    clean(padding_dir)

# %%
import math
from sklearn import preprocessing
import pywt
import numpy as np
import sys
import os
import glob
import sh
import matplotlib.pyplot as plt
import util
import librosa


def  get_teager_energy(wp,Node,n,N_limit):
    k_len = 12
    TC = []
    for k in range(k_len):
        sum = 0
        for l in range(2**n):
            el = get_e(l,N_limit,wp,Node)
            sum += math.log(np.abs(el),2) * math.cos(k*(l-0.5)*math.pi/(2**n))
        TC.append(sum)
    return TC

def get_e(l,N_limit,wp,Node):
    name = Node[l]
    x = wp[name].data
    sum = 0
    for t in range(N_limit):

        sum += x[t+1]*x[t+1]-x[t]*x[t+2]
        #print sum
    el = float(sum/N_limit)
    return el

def extration_wavelet_packet(wavFile):

    sig, fs = librosa.load(wavFile)
#     print("fs is ",fs)
#     print("signal length is ", len(sig))
    N_signal = len(sig)
    n_level = 6

    wp = pywt.WaveletPacket(data=sig, wavelet='db3', mode='symmetric')

    Node = []
    N_limit = 16
    limit = 0
    for node in wp.get_level(6, 'natural'):
            Node.append(node.path)

#     print("sub sample is ",len(Node))

    TC = get_teager_energy(wp,Node,n_level,N_limit)
    print ("TC is ",TC)
    return TC


def extration_mfcc(wavFile):

    # Read the wav file
    X, sample_rate = librosa.load(wavFile)
#     print("sample_rate  is ",sample_rate )
#     print("data is ", X)

    # sftf
#     stft = np.abs(librosa.stft(X))

    # mfcc
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=13).T,axis=0)
    '''
    # chroma
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)

    # melspectrogram
    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)

    # spectral contrast
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)

    return mfccs,chroma,mel,contrast
    '''
    return mfccs

def extration_rawSignal(wavFile,max_len,sample_rate):

    # Read the wav file
    X, sample_rate = librosa.load(wavFile, sr=sample_rate, mono=True)
    # print("sample_rate  is ",sample_rate )
    # print("data is ", X)
    # print X.shape
    if X.shape[0] < max_len:
        pad = np.zeros(max_len - X.shape[0])
        # print("pad is ",pad)
        X = np.hstack((X, pad))
    elif X.shape[0] > max_len:
        X = X[:max_len]
    # print X.shape
    return X



def parse_audio_files_rawSignal(redimension_dir,sub_read,file_ext):
    max_len=200
    sample_rate=100
    features, labels = np.empty((0,max_len)), np.empty(0)
    for label, sub_dir in enumerate(sub_read):
#         print("label: %s" % (label))
        #print("sub_dir: %s" % (sub_dir))
        for f in glob.glob(os.path.join(redimension_dir, sub_dir, file_ext)):
            print("extract file: %s" % (f))
            waveFile_name = (os.path.splitext(f)[0]).split(os.sep)[2]
            try:
                audio = extration_rawSignal(f,max_len,sample_rate)

            except Exception as e:
                print("[Error] extract feature error. %s" % (e))
                continue

            ext_features = np.hstack([audio])
            #print len(ext_features)
            #print ext_features
            features = np.vstack([features,ext_features])
            # labels = np.append(labels, quality)
            labels = np.append(labels, label)
        # print (features.shape)
        #print features
        #print labels
    return np.array(features), np.array(labels, dtype = np.int)


def parse_audio_files_waveletPackets(read_dir,sub_read,file_ext):
    features, labels = np.empty((0,12)), np.empty(0)
    for label, sub_dir in enumerate(sub_read):
#         print("label: %s" % (label))
        #print("sub_dir: %s" % (sub_dir))
        for f in glob.glob(os.path.join(read_dir, sub_dir, file_ext)):
            print("extract file: %s" % (f))
            waveFile_name = (os.path.splitext(f)[0]).split(os.sep)[2]
            quality = util.splitext(waveFile_name)[2]
            try:
                TC = extration_wavelet_packet(f)

            except Exception as e:
                print("[Error] extract feature error. %s" % (e))
                continue

            ext_features = np.hstack([TC])
            #print len(ext_features)
            #print ext_features
            features = np.vstack([features,ext_features])
            # labels = np.append(labels, quality)
            labels = np.append(labels, label)
#         print (features.shape)
        #print features
        #print labels
    return np.array(features), np.array(labels, dtype = np.int)


def parse_audio_files_mfcc(read_dir,sub_read,file_ext):
    features, labels = np.empty((0,13)), np.empty(0)
    for label, sub_dir in enumerate(sub_read):
#         print("label: %s" % (label))
        #print("sub_dir: %s" % (sub_dir))
        for f in glob.glob(os.path.join(read_dir, sub_dir, file_ext)):
            print("extract file: %s" % (f))
            waveFile_name = (os.path.splitext(f)[0]).split(os.sep)[2]
            quality = util.splitext(waveFile_name)[2]
            try:
                mfccs = extration_mfcc(f)
                # print len(mfccs),len(chroma),len(mel),len(contrast)
                print (len(mfccs))
                #print ("mfcc is",np.array(mfccs))
            except Exception as e:
                print("[Error] extract feature error. %s" % (e))
                continue

            # ext_features = np.hstack([mfccs,chroma,mel,contrast])
            ext_features = np.hstack([mfccs])
            #print len(ext_features)
            #print ext_features
            features = np.vstack([features,ext_features])
            # labels = np.append(labels, quality)
            labels = np.append(labels, label)
#         print (features.shape)
#         print (features)
        #print labels
    return np.array(features), np.array(labels, dtype = np.int)


def normaliser_features(features):

    features_normalisation = preprocessing.scale(features)

    return features_normalisation



def encode_label(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    labels_encode = np.zeros((n_labels,1))
    #print labels_encode
    for i in range(n_labels):
        labels_encode[i]= labels[i]

    return labels_encode


if __name__ == "__main__":

    read_dir = "read"
    sub_read = ['Bm','Eg']
    file_ext='*.wav'
    
    cmd = "rm -rf feature/*"
    sh.run(cmd)
    ############ mfcc

    features_mfcc,labels_mfcc = parse_audio_files_mfcc(read_dir,sub_read,file_ext)
    features_mfcc = normaliser_features(features_mfcc)
    # print ("features noramallisation are ",features_normalisation)
    labels_mfcc = encode_label(labels_mfcc)
    # print ("label encode is ",labels_encode)
    #print type(labels_encode)

    np.savetxt("feature/train_features_mfcc.txt",features_mfcc)
    np.savetxt("feature/train_label_mfcc.txt",labels_mfcc)
    
    ############ wavelet
    features_wavelet,labels_wavelet = parse_audio_files_waveletPackets(read_dir,sub_read,file_ext)
    features_wavelet = normaliser_features(features_wavelet)
    labels_wavelet = encode_label(labels_wavelet)

    np.savetxt("feature/train_features_wavelet.txt",features_wavelet)
    np.savetxt("feature/train_label_wavelet.txt",labels_wavelet)
    
    ###########  raw signal
    
    features_rawSignal,labels_rawSignal = parse_audio_files_rawSignal(read_dir,sub_read,file_ext)
    features_rawSignal = normaliser_features(features_rawSignal)
    labels_rawSignal = encode_label(labels_rawSignal)
    
    np.savetxt("feature/train_features_rawSignal.txt",features_rawSignal)
    np.savetxt("feature/train_label_rawSignal.txt",labels_rawSignal)

# %%
import sys
import os
import glob

import numpy as np
import math
import matplotlib.pyplot as plt

import util
from extration import *

from sklearn import preprocessing,metrics

import torch
from torch import nn
from torch.autograd import Variable
from torch.nn import init
import torch.utils.data as Data
import torch.nn.functional as F


hidden_size = 80
num_layers = 2
num_classes = 3
batch_size = 1
num_epochs = 1



class RNN(nn.Module):

    def __init__(self, input_size, hidden_size, num_layers, num_classes,drop_out):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True,dropout=drop_out)

        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # Set initial states
        h0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))
        c0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))

        # Forward propagate RNN
        out, _ = self.lstm(x, (h0, c0))

       # print (out.size())
        # Decode hidden state of last time step
        out = self.fc(out[:, -1, :])
        return out



def split_data(train_features,train_labels):
    # random train and test sets.
    # train_test_split(features_normalization, lable[0], test_size = 0.2, random_state=0)
    #print np.random.rand(len(train_features))
    train_test_split = np.random.rand(len(train_features)) < 0.70
    #print train_test_split
    train_x = train_features[train_test_split]
    train_y = train_labels[train_test_split]
    test_x = train_features[~train_test_split]
    test_y = train_labels[~train_test_split]

    #print train_x.shape,train_y.shape
    return train_x,train_y,test_x,test_y



def train_rnn(features_normalisation,labels_encode,learning_rate,optimizer,drop_out,type):

    train_x,train_y,test_x,test_y = split_data(features_normalisation,labels_encode)
    x, y = torch.from_numpy(train_x).float(), torch.from_numpy(train_y).long()
    train_dataset = Data.TensorDataset(x, y)
    train_loader = Data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=2,)
    #print("train x is ",train_x)
    #print("train y is ",train_y)
    # x_temp =  train_x[ : , np.newaxis , :]
    # print x_temp.shape
    # x, y = Variable(torch.Tensor(x_temp)), Variable(torch.LongTensor(train_y))

    test_x1, test_y1 = torch.from_numpy(test_x).float(), torch.from_numpy(test_y).long()
    test_x = Variable(test_x1, requires_grad=False).type(torch.FloatTensor)
    test_y = test_y1.numpy().squeeze() # covert to numpy array

    if type =='mfcc':
        input_size = 13
    elif type =='wavelet':
        input_size = 12
    elif type == 'rawSignal':
        input_size =200

    rnn = RNN(input_size, hidden_size, num_layers, num_classes,drop_out)
    # print(rnn)

    if optimizer == 'Adam':
        optimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate)
    else:
        optimizer = torch.optim.SGD(rnn.parameters(), lr=learning_rate)
    loss_func = nn.CrossEntropyLoss()

    acc = []

    for epoch in range(num_epochs):
        for step, (x, y) in enumerate(train_loader):   # gives batch data
            #print (x.shape)
            if type =='mfcc':
                b_x = Variable(x.view(-1,1,13), requires_grad=False)
            elif type =='wavelet':
                b_x = Variable(x.view(-1,1,12), requires_grad=False)
            elif type == 'rawSignal':
                b_x = Variable(x.view(-1,1,200), requires_grad=False)
            #print (b_x.shape)
            #print b_x
            b_y = Variable(y.view(-1), requires_grad=False)   # batch y
            # print (b_y)
            # output = net(b_x)               # rnn output
            output = rnn(b_x)
            # print output
            loss = loss_func(output, b_y)   # cross entropy loss
            optimizer.zero_grad()           # clear gradients for this training step
            loss.backward()                 # backpropagation, compute gradients
            optimizer.step()                # apply gradients

            if step % 50 == 0:
                if type =='mfcc':
                    test_output = rnn(test_x.view(-1,1,13))
                elif type =='wavelet':
                    test_output = rnn(test_x.view(-1,1,12))
                elif type == 'rawSignal':
                    test_output = rnn(test_x.view(-1,1,200))

                pred_y = torch.max(test_output, 1)[1].data.numpy().squeeze()
                accuracy = sum(pred_y == test_y) / float(test_y.size)
                acc.append(accuracy)

                print('Epoch: ', epoch, '| train loss: %.4f' % loss.data[0], '| test accuracy: %.4f' % accuracy)

    if type =='mfcc':
        pre_output = rnn(test_x.view(-1,1,13))
    elif type =='wavelet':
        pre_output = rnn(test_x.view(-1,1,12))
    elif type == 'rawSignal':
        pre_output = rnn(test_x.view(-1,1,200))
    pred_y = torch.max(pre_output, 1)[1].data.numpy().squeeze()
    # accuracy = sum(pred_y == test_y) / float(test_y.size)
    print (metrics.classification_report(test_y, pred_y))


    return max(acc),rnn



if __name__ == "__main__":
    
    
    cmd = "rm -rf model/*"
    sh.run(cmd)

    learning_rate = 0.01
    optimizer = 'Adam'
    dropout = 0.05
    types = ['mfcc','wavelet','rawSignal']
    features_mfcc = np.loadtxt("feature/train_features_mfcc.txt")
    labels_mfcc = np.loadtxt("feature/train_label_mfcc.txt")
    # print np.unique(labels_mfcc)

    features_wavelet = np.loadtxt("feature/train_features_wavelet.txt")
    labels_wavelet = np.loadtxt("feature/train_label_wavelet.txt")
    # print np.unique(labels_wavelet)

    features_rawSignal = np.loadtxt("feature/train_features_rawSignal.txt")
    labels_rawSignal = np.loadtxt("feature/train_label_rawSignal.txt")
    # print np.unique(labels_rawSignal)

    for type in types:
        print(type)
        if type =='mfcc':
            _,rnn1 = train_rnn(features_mfcc,labels_mfcc,learning_rate,optimizer,dropout,type)
            torch.save(rnn1, 'model/mfcc_model_lstm.pkl')
        elif type == 'wavelet':
            _,rnn2 = train_rnn(features_wavelet,labels_wavelet,learning_rate,optimizer,dropout,type)
            torch.save(rnn2, 'model/wavelet_model_lstm.pkl')
        elif type == 'rawSignal':
            _,rnn3 = train_rnn(features_rawSignal,labels_rawSignal,learning_rate,optimizer,dropout,type)
            torch.save(rnn3, 'model/rawSignal_model_lstm.pkl')
            
    '''        
            
    type = 'mfcc'
    features_mfcc = np.loadtxt("feature/train_features_mfcc.txt")
    labels_mfcc = np.loadtxt("feature/train_label_mfcc.txt")
    learning_rate = [0.01,0.1,0.5]
    opt = ['Adam','SGD']
    drop_out = [0.05,0.1,0.2]

    best_acc = 0

    for lr in learning_rate:
        for op in opt:
            for do in drop_out:
                accuracy,rnn = train_rnn(features_mfcc,labels_mfcc,lr,op,do,type)
                print('learning_rate:' ,lr,'| optimizer: ',op,'| dropout: ',do,'| accuracy: ',accuracy)

                if accuracy < best_acc:
                    print('Accuracy was not improved')
                else:
                    print('Saving model...')
                    best_acc = accuracy
                    torch.save(rnn, 'model/best_mfcc_model_lstm.pkl')
    '''
# Out:
# rm -rf model/*
# mfcc
# ('Epoch: ', 0, '| train loss: 1.1530', '| test accuracy: 0.6546')
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:138: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# ('Epoch: ', 0, '| train loss: 0.0005', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0753', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0247', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.2687', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0027', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0131', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0004', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0002', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0054', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0050', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0004', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0023', '| test accuracy: 0.9729')
# ('Epoch: ', 0, '| train loss: 0.0006', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0002', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0000', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0000', '| test accuracy: 0.9620')
# ('Epoch: ', 0, '| train loss: 0.0021', '| test accuracy: 0.9729')
# ('Epoch: ', 0, '| train loss: 0.0000', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0001', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0000', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0290', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0011', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0184', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0000', '| test accuracy: 0.9765')
# ('Epoch: ', 0, '| train loss: 0.0003', '| test accuracy: 0.9765')
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99       540
#           1       0.00      0.00      0.00        13
#
# avg / total       0.95      0.98      0.96       553
#
# wavelet
# /home/sheng/.local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ('Epoch: ', 0, '| train loss: 1.1339', '| test accuracy: 0.3393')
# ('Epoch: ', 0, '| train loss: 0.0000', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0052', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.1596', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0005', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0022', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.1746', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0005', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0185', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0038', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0101', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0041', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0048', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0847', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0080', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0043', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0068', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0049', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.1328', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0207', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0018', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0306', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0224', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0505', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0233', '| test accuracy: 0.9713')
# ('Epoch: ', 0, '| train loss: 0.0351', '| test accuracy: 0.9713')
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99       541
#           1       0.00      0.00      0.00        16
#
# avg / total       0.94      0.97      0.96       557
#
# rawSignal
# ('Epoch: ', 0, '| train loss: 1.0471', '| test accuracy: 0.9636')
# ('Epoch: ', 0, '| train loss: 0.0000', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0000', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.4715', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0003', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0246', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0016', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0074', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0006', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0748', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0012', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0001', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0108', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0075', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0433', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0066', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0076', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0085', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0023', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0005', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0036', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0003', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0004', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0002', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0041', '| test accuracy: 0.9727')
# ('Epoch: ', 0, '| train loss: 0.0004', '| test accuracy: 0.9727')
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99       534
#           1       0.00      0.00      0.00        15
#
# avg / total       0.95      0.97      0.96       549
